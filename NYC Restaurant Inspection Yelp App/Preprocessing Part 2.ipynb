# %%
import pandas as pd 
import pickle 
import numpy as np 
from sqlalchemy import create_engine
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# Load Dataset

# %%
df = pd.read_pickle('merged.pkl')

# %%
df.dtypes
# Out:
# camis                      int64
# dba                       object
# boro                      object
# building                  object
# street                    object
# zipcode                   object
# inspection_date           object
# critical_flag             object
# record_date               object
# latitude                 float64
# longitude                float64
# cuisine_description       object
# action                    object
# violation_code            object
# violation_description     object
# score                    float64
# inspection_type           object
# grade                     object
# grade_date                object
# address                   object
# clean address             object
# latitude_clean           float64
# longitude_clean          float64
# zipcode_clean             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228770 entries, 0 to 275867
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   camis                  228770 non-null  int64
#  1   dba                    228770 non-null  object
#  2   boro                   228770 non-null  object
#  3   building               228463 non-null  object
#  4   street                 228770 non-null  object
#  5   zipcode                228770 non-null  object
#  6   inspection_date        228770 non-null  object
#  7   critical_flag          228770 non-null  object
#  8   record_date            228770 non-null  object
#  9   latitude               228770 non-null  float64
#  10  longitude              228770 non-null  float64
#  11  cuisine_description    228770 non-null  object
#  12  action                 228770 non-null  object
#  13  violation_code         226980 non-null  object
#  14  violation_description  226980 non-null  object
#  15  score                  221156 non-null  float64
#  16  inspection_type        228770 non-null  object
#  17  grade                  112192 non-null  object
#  18  grade_date             105407 non-null  object
#  19  address                228463 non-null  object
#  20  clean address          3296 non-null    object
#  21  latitude_clean         3296 non-null    float64
#  22  longitude_clean        3296 non-null    float64
#  23  zipcode_clean          3296 non-null    object
# dtypes: float64(5), int64(1), object(18)
# memory usage: 43.6+ MB

# %%
#drop columns not needed 
df.drop(['clean address', 'latitude_clean', 'longitude_clean', 'zipcode_clean'], axis = 1, inplace = True)

# %% [markdown]
# Impute Missing Address with Street name

# %%
x = df[df.address.isna() & df.street.notnull()]
x
# Out:
#            camis                                                dba  \
# 1040    50001249  TIGIN IRISH PUB, PEETS COFFEE&TEA/CANAL STREET...
# 1947    50008956                                QDOBA MEXICAN GRILL
# 4726    50000413                                   UPTOWN BRASSERIE
# 5236    41362369                                  FOOD HALL KITCHEN
# 7262    50062391                                    EMIRATES LOUNGE
# ...          ...                                                ...
# 272848  50086798                                         JOE COFFEE
# 272887  50001777                                        AU BON PAIN
# 274399  50001777                                        AU BON PAIN
# 275675  41258883                                            O'NEALS
# 275778  50008956                                QDOBA MEXICAN GRILL
#
#              boro building                     street  zipcode  \
# 1040       Queens      NaN  JFK INTERNATIONAL AIRPORT  11430.0
# 1947       Queens      NaN  JFK INTERNATIONAL AIRPORT  11430.0
# 4726       Queens      NaN  JFK INTERNATIONAL AIRPORT  11430.0
# 5236       Queens      NaN  JFK INTERNATIONAL AIRPORT  11430.0
# 7262       Queens      NaN  JFK INTERNATIONAL AIRPORT  11430.0
# ...           ...      ...                        ...      ...
# 272848  Manhattan      NaN     GRAND CENTRAL TERMINAL  10017.0
# 272887     Queens      NaN  JFK INTERNATIONAL AIRPORT  11430.0
# 274399     Queens      NaN  JFK INTERNATIONAL AIRPORT  11430.0
# 275675     Queens      NaN  JFK INTERNATIONAL AIRPORT  11430.0
# 275778     Queens      NaN  JFK INTERNATIONAL AIRPORT  11430.0
#
#                 inspection_date critical_flag              record_date  \
# 1040    2017-02-22T00:00:00.000      Critical  2022-08-27T06:00:12.000
# 1947    2016-11-16T00:00:00.000      Critical  2022-08-27T06:00:12.000
# 4726    2018-08-16T00:00:00.000  Not Critical  2022-08-27T06:00:12.000
# 5236    2020-02-10T00:00:00.000  Not Critical  2022-08-27T06:00:12.000
# 7262    2019-05-30T00:00:00.000      Critical  2022-08-27T06:00:12.000
# ...                         ...           ...                      ...
# 272848  2021-08-10T00:00:00.000      Critical  2022-08-27T06:00:12.000
# 272887  2017-11-01T00:00:00.000  Not Critical  2022-08-27T06:00:12.000
# 274399  2017-02-23T00:00:00.000  Not Critical  2022-08-27T06:00:12.000
# 275675  2022-06-01T00:00:00.000  Not Critical  2022-08-27T06:00:12.000
# 275778  2016-09-12T00:00:00.000  Not Critical  2022-08-27T06:00:12.000
#
#          latitude  longitude      cuisine_description  \
# 1040    40.648313 -73.788281                 American
# 1947    40.648313 -73.788281                  Mexican
# 4726    40.648313 -73.788281                 American
# 5236    40.648313 -73.788281                 American
# 7262    40.648313 -73.788281           Middle Eastern
# ...           ...        ...                      ...
# 272848  40.752486 -73.977269               Coffee/Tea
# 272887  40.648313 -73.788281  Soups/Salads/Sandwiches
# 274399  40.648313 -73.788281  Soups/Salads/Sandwiches
# 275675  40.648313 -73.788281                 American
# 275778  40.648313 -73.788281                  Mexican
#
#                                                  action violation_code  \
# 1040    Violations were cited in the following area(s).            04N
# 1947    Violations were cited in the following area(s).            04N
# 4726    Violations were cited in the following area(s).            22A
# 5236    Violations were cited in the following area(s).            10F
# 7262    Violations were cited in the following area(s).            02B
# ...                                                 ...            ...
# 272848  Violations were cited in the following area(s).            04L
# 272887  Violations were cited in the following area(s).            08A
# 274399  Violations were cited in the following area(s).            10F
# 275675  Violations were cited in the following area(s).            10F
# 275778  Violations were cited in the following area(s).            08A
#
#                                     violation_description  score  \
# 1040    Filth flies or food/refuse/sewage-associated (...   13.0
# 1947    Filth flies or food/refuse/sewage-associated (...   21.0
# 4726    Nuisance created or allowed to exist.  Facilit...    NaN
# 5236    Non-food contact surface improperly constructe...    6.0
# 7262           Hot food item not held at or above 140º F.   12.0
# ...                                                   ...    ...
# 272848  Evidence of mice or live mice present in facil...   13.0
# 272887  Facility not vermin proof. Harborage or condit...   12.0
# 274399  Non-food contact surface improperly constructe...   25.0
# 275675  Non-food contact surface improperly constructe...    4.0
# 275778  Facility not vermin proof. Harborage or condit...   29.0
#
#                                           inspection_type grade  \
# 1040                Cycle Inspection / Initial Inspection     A
# 1947                     Cycle Inspection / Re-inspection     B
# 4726    Administrative Miscellaneous / Initial Inspection   NaN
# 5236                     Cycle Inspection / Re-inspection     A
# 7262                Cycle Inspection / Initial Inspection     A
# ...                                                   ...   ...
# 272848              Cycle Inspection / Initial Inspection     A
# 272887              Cycle Inspection / Initial Inspection     A
# 274399              Cycle Inspection / Initial Inspection   NaN
# 275675              Cycle Inspection / Initial Inspection     A
# 275778              Cycle Inspection / Initial Inspection   NaN
#
#                      grade_date address
# 1040    2017-02-22T00:00:00.000     NaN
# 1947    2016-11-16T00:00:00.000     NaN
# 4726                        NaN     NaN
# 5236    2020-02-10T00:00:00.000     NaN
# 7262    2019-05-30T00:00:00.000     NaN
# ...                         ...     ...
# 272848  2021-08-10T00:00:00.000     NaN
# 272887  2017-11-01T00:00:00.000     NaN
# 274399                      NaN     NaN
# 275675  2022-06-01T00:00:00.000     NaN
# 275778                      NaN     NaN
#
# [307 rows x 20 columns]

# %%
#replace missing address with street name (JFK International Airport, Central Terminal)
mask1 = df['address'].isna()

mask2 = df.street.notnull()

df['address'] = np.where(mask1 & mask2, df['street'], df['address'])

# %%
#check if method worked
x = df[df.address.isna() & df.street.notnull()]
x
# Out:
# Empty DataFrame
# Columns: [camis, dba, boro, building, street, zipcode, inspection_date, critical_flag, record_date, latitude, longitude, cuisine_description, action, violation_code, violation_description, score, inspection_type, grade, grade_date, address]
# Index: []

# %% [markdown]
# Convert Inspection Date to Datetime

# %%
df.inspection_date.value_counts()
# Out:
# 2019-10-30T00:00:00.000    640
# 2019-11-07T00:00:00.000    631
# 2022-05-12T00:00:00.000    621
# 2019-10-24T00:00:00.000    616
# 2020-01-22T00:00:00.000    608
#                           ...
# 2021-05-12T00:00:00.000      1
# 2018-07-22T00:00:00.000      1
# 2016-08-09T00:00:00.000      1
# 2022-04-09T00:00:00.000      1
# 2016-07-30T00:00:00.000      1
# Name: inspection_date, Length: 1618, dtype: int64

# %%
df.inspection_date.str.contains('T00:00:00.000').sum()
# Out:
# 228770

# %%
df.inspection_date = df.inspection_date.str.replace('T00:00:00.000', '')

# %%
df['inspection_date'] = pd.to_datetime(df['inspection_date'], format='%Y-%m-%d')

# %%
df.dtypes
# Out:
# camis                             int64
# dba                              object
# boro                             object
# building                         object
# street                           object
# zipcode                          object
# inspection_date          datetime64[ns]
# critical_flag                    object
# record_date                      object
# latitude                        float64
# longitude                       float64
# cuisine_description              object
# action                           object
# violation_code                   object
# violation_description            object
# score                           float64
# inspection_type                  object
# grade                            object
# grade_date                       object
# address                          object
# dtype: object

# %%
df.inspection_date.unique()
# Out:
# array(['2017-08-25T00:00:00.000000000', '2022-07-07T00:00:00.000000000',
#        '2022-04-11T00:00:00.000000000', ...,
#        '2021-10-03T00:00:00.000000000', '2016-03-07T00:00:00.000000000',
#        '2016-07-30T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df.inspection_date.value_counts()
# Out:
# 2019-10-30    640
# 2019-11-07    631
# 2022-05-12    621
# 2019-10-24    616
# 2020-01-22    608
#              ...
# 2021-05-12      1
# 2018-07-22      1
# 2016-08-09      1
# 2022-04-09      1
# 2016-07-30      1
# Name: inspection_date, Length: 1618, dtype: int64

# %%
# for selecting month-year range for app 
a= df.inspection_date.drop_duplicates().sort_values()


a
# Out:
# 13780    2015-01-06
# 169643   2015-06-25
# 162873   2015-07-08
# 120177   2015-09-24
# 119039   2015-10-14
#             ...
# 16003    2022-08-20
# 459      2022-08-22
# 3191     2022-08-23
# 356      2022-08-24
# 809      2022-08-25
# Name: inspection_date, Length: 1618, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228770 entries, 0 to 275867
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   camis                  228770 non-null  int64
#  1   dba                    228770 non-null  object
#  2   boro                   228770 non-null  object
#  3   building               228463 non-null  object
#  4   street                 228770 non-null  object
#  5   zipcode                228770 non-null  object
#  6   inspection_date        228770 non-null  datetime64[ns]
#  7   critical_flag          228770 non-null  object
#  8   record_date            228770 non-null  object
#  9   latitude               228770 non-null  float64
#  10  longitude              228770 non-null  float64
#  11  cuisine_description    228770 non-null  object
#  12  action                 228770 non-null  object
#  13  violation_code         226980 non-null  object
#  14  violation_description  226980 non-null  object
#  15  score                  221156 non-null  float64
#  16  inspection_type        228770 non-null  object
#  17  grade                  112192 non-null  object
#  18  grade_date             105407 non-null  object
#  19  address                228770 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(15)
# memory usage: 36.7+ MB

# %% [markdown]
# Check for Duplicates & drop duplicates

# %%
# sort values by critical flag so that score 
#reflects for restaurants with critical + non critical violations on the same day as critical 
#when dropping duplicates

df = df.sort_values(['critical_flag'])

# %%
#check for duplicates on given datetime

(df.groupby(['camis', 'dba', 'inspection_date', 'cuisine_description'])
 .score.count().reset_index().sort_values('score', ascending = False))
# Out:
#           camis                                   dba inspection_date  \
# 67813  50105938                                  SUKI      2021-11-30
# 68192  50106646             Secret Paradise Grill Inc      2022-08-22
# 61304  50089761                            15 FLAVORS      2022-03-24
# 45215  50056824                         HUNDRED TASTE      2022-07-20
# 38957  50042658         FISH & SHRIMP RESTAURANT SPOT      2022-08-02
# ...         ...                                   ...             ...
# 25483  41683539       HAPPY GARDEN CHINESE RESTAURANT      2018-12-17
# 54787  50076107                                 LUCKY      2021-06-16
# 25442  41682958  EL ANCLA DE ASTORIA RESTAURANT & BAR      2016-11-03
# 54768  50076079                        CHINITO LATINO      2019-03-12
# 31130  50005981                  AROMA DE CAFE BAKERY      2019-08-28
#
#       cuisine_description  score
# 67813            Japanese     18
# 68192              Creole     16
# 61304     Frozen Desserts     16
# 45215             Chinese     16
# 38957      Latin American     15
# ...                   ...    ...
# 25483             Chinese      0
# 54787               Other      0
# 25442            Peruvian      0
# 54768       Chinese/Cuban      0
# 31130      Latin American      0
#
# [72641 rows x 5 columns]

# %%
mask = ((df['camis'] ==50105938) &
       (df['dba'] =="SUKI") &
       (df['inspection_date'].dt.date == datetime.datetime(2021,11,30).date()) &
       (df['cuisine_description'] =="Japanese")
       
)
df[mask]
# 10251   105.0      Pre-permit (Operational) / Initial Inspection   NaN
# 22552   105.0      Pre-permit (Operational) / Initial Inspection   NaN
# 86872   105.0      Pre-permit (Operational) / Initial Inspection   NaN
# 255949  105.0      Pre-permit (Operational) / Initial Inspection   NaN
# 11386     NaN  Administrative Miscellaneous / Initial Inspection   NaN
# 161579  105.0      Pre-permit (Operational) / Initial Inspection   NaN
# 145400  105.0      Pre-permit (Operational) / Initial Inspection   NaN
# 202362  105.0      Pre-permit (Operational) / Initial Inspection   NaN
# 176481  105.0      Pre-permit (Operational) / Initial Inspection   NaN
#
#        grade_date           address
# 176319        NaN  111 1 AVENUE NYC
# 173093        NaN  111 1 AVENUE NYC
# 130762        NaN  111 1 AVENUE NYC
# 232498        NaN  111 1 AVENUE NYC
# 271960        NaN  111 1 AVENUE NYC
# 231347        NaN  111 1 AVENUE NYC
# 227489        NaN  111 1 AVENUE NYC
# 44237         NaN  111 1 AVENUE NYC
# 68855         NaN  111 1 AVENUE NYC
# 63111         NaN  111 1 AVENUE NYC
# 10251         NaN  111 1 AVENUE NYC
# 22552         NaN  111 1 AVENUE NYC
# 86872         NaN  111 1 AVENUE NYC
# 255949        NaN  111 1 AVENUE NYC
# 11386         NaN  111 1 AVENUE NYC
# 161579        NaN  111 1 AVENUE NYC
# 145400        NaN  111 1 AVENUE NYC
# 202362        NaN  111 1 AVENUE NYC
# 176481        NaN  111 1 AVENUE NYC

# %%
#get rid of duplicates
df.drop_duplicates(subset =['camis', 'dba', 'inspection_date', 'cuisine_description'], inplace =True)

# %%
#check if duplicates are gone
#check for duplicates on given datetime

(df.groupby(['camis', 'dba', 'inspection_date', 'cuisine_description'])
 .score.count().reset_index().sort_values('score', ascending = False))
# Out:
#           camis                                                dba  \
# 0      30075445  Test test Test test Test test Test test Test t...
# 48282  50063620                                        DIAMOND LIL
# 48288  50063627                                    JOE & THE JUICE
# 48287  50063625                                       UTOPIA DINER
# 48286  50063625                                       UTOPIA DINER
# ...         ...                                                ...
# 17599  41450971                              GIOVANNI'S RESTAURANT
# 69471  50109601                                   INSOMNIA COOKIES
# 46932  50059875                                1ST MAMA RESTAURANT
# 57128  50081412                                           GAZALA'S
# 1843   40394207                                           PASCALOU
#
#       inspection_date             cuisine_description  score
# 0          2019-05-16        Bakery Products/Desserts      1
# 48282      2017-10-14                        American      1
# 48288      2019-07-01  Juice, Smoothies, Fruit Salads      1
# 48287      2022-05-02                        American      1
# 48286      2020-02-27                        American      1
# ...               ...                             ...    ...
# 17599      2018-12-20                           Pizza      0
# 69471      2022-07-13                        American      0
# 46932      2020-01-09                  Latin American      0
# 57128      2022-05-19                   Mediterranean      0
# 1843       2019-01-23                          French      0
#
# [72641 rows x 5 columns]

# %%
mask = ((df['camis'] ==50105938) &
       (df['dba'] =="SUKI") &
       (df['inspection_date'].dt.date == datetime.datetime(2021,11,30).date()) &
       (df['cuisine_description'] =="Japanese")
       
)
df[mask]
# Out:
#            camis   dba       boro building    street  zipcode inspection_date  \
# 176319  50105938  SUKI  Manhattan      111  1 AVENUE  10003.0      2021-11-30
#
#        critical_flag              record_date   latitude  longitude  \
# 176319      Critical  2022-08-27T06:00:12.000  40.726827 -73.985853
#
#        cuisine_description                                             action  \
# 176319            Japanese  Establishment Closed by DOHMH. Violations were...
#
#        violation_code                              violation_description  \
# 176319            06E  Sanitized equipment or utensil, including in-u...
#
#         score                                inspection_type grade grade_date  \
# 176319  105.0  Pre-permit (Operational) / Initial Inspection   NaN        NaN
#
#                  address
# 176319  111 1 AVENUE NYC

# %%
df.shape
# Out:
# (72641, 20)

# %% [markdown]
# Impute missing values for Grade Category

# %%
df.grade.value_counts()
# Out:
# A    39195
# B     3002
# N     1602
# C     1026
# Z      861
# P      610
# Name: grade, dtype: int64

# %%
df.grade.unique()
# Out:
# array([nan, 'A', 'C', 'N', 'B', 'Z', 'P'], dtype=object)

# %%
df['grade'] = df['grade'].replace(np.nan, 'Missing Grade')

# %%
df['grade'] = df['grade'].replace('N', 'Not Yet Graded')
df['grade'] = df['grade'].replace('Z', 'Grade Pending')
df['grade'] = df['grade'].replace('P', 'Grade Pending resulted in a closure')

# %%
df.grade.value_counts()
# Out:
# A                                      39195
# Missing Grade                          26345
# B                                       3002
# Not Yet Graded                          1602
# C                                       1026
# Grade Pending                            861
# Grade Pending resulted in a closure      610
# Name: grade, dtype: int64

# %% [markdown]
# Impute Missing Score values w/ median zipcode score of matched zipcode

# %%
zipcode_map = (df.query('score.notnull()')
              .drop_duplicates('zipcode')
              .set_index('zipcode')
              .score)

zipcode_map
# Out:
# zipcode
# 11225.0    24.0
# 10475.0    77.0
# 10012.0     7.0
# 11209.0     9.0
# 10465.0    34.0
#            ...
# 11214       7.0
# 11105       0.0
# 11241.0     5.0
# 10199      12.0
# 10470       2.0
# Name: score, Length: 325, dtype: float64

# %%
df['score'] = df['zipcode'].map(zipcode_map).fillna(np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72641 entries, 0 to 186097
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   camis                  72641 non-null  int64
#  1   dba                    72641 non-null  object
#  2   boro                   72641 non-null  object
#  3   building               72511 non-null  object
#  4   street                 72641 non-null  object
#  5   zipcode                72641 non-null  object
#  6   inspection_date        72641 non-null  datetime64[ns]
#  7   critical_flag          72641 non-null  object
#  8   record_date            72641 non-null  object
#  9   latitude               72641 non-null  float64
#  10  longitude              72641 non-null  float64
#  11  cuisine_description    72641 non-null  object
#  12  action                 72641 non-null  object
#  13  violation_code         71345 non-null  object
#  14  violation_description  71345 non-null  object
#  15  score                  72641 non-null  float64
#  16  inspection_type        72641 non-null  object
#  17  grade                  72641 non-null  object
#  18  grade_date             44697 non-null  object
#  19  address                72641 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(15)
# memory usage: 11.6+ MB

# %%
#save to pickple
df.to_pickle('final_clean.pkl')
