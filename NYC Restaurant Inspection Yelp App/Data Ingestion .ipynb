# %%
import pandas as pd 
from sodapy import Socrata 
from sqlalchemy import create_engine

# %%
#works for public data sets --'None', authenticated client uses username + password with apptoken 
client = Socrata("data.cityofnewyork.us",
                 "QRpUzYLtBj9TWPAs8SvwubsEb", 
                 username = "hannahdazey2@gmail.com", 
                 password = "Nj!i9KFc*@c39T5")

#return the first 2000 results that are converted to python lists

results = client.get('43nn-pn8j', limit = 260000)

# %%
#convert to pandas DF

results_df = pd.DataFrame.from_records(results)

# %%
results_df.head()
# Out:
#       camis                       dba       boro building  \
# 0  50115383              MAKE MY CAKE  Manhattan      409
# 1  50101317              THE FLO KISS  Manhattan     1802
# 2  50109634  QUICK EATS AT MASTERCARD  Manhattan      150
# 3  50124605                       NaN  Manhattan       37
# 4  50112662                       NaN  Manhattan      512
#
#                   street zipcode       phone          inspection_date  \
# 0       WEST  125 STREET   10027  9174405783  1900-01-01T00:00:00.000
# 1  65TH STREET TRANVERSE     NaN  6466453020  1900-01-01T00:00:00.000
# 2               5 AVENUE   10011  2152383000  1900-01-01T00:00:00.000
# 3      SAINT MARKS PLACE   10003  9174788158  1900-01-01T00:00:00.000
# 4               7 AVENUE   10018  9292676606  1900-01-01T00:00:00.000
#
#     critical_flag              record_date  ...         bbl   nta  \
# 0  Not Applicable  2022-08-27T06:00:16.000  ...  1019660066  MN09
# ...

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248020 entries, 0 to 248019
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   camis                  248020 non-null  object
#  1   dba                    246430 non-null  object
#  2   boro                   248020 non-null  object
#  3   building               247552 non-null  object
#  4   street                 248020 non-null  object
#  5   zipcode                244464 non-null  object
#  6   phone                  247998 non-null  object
#  7   inspection_date        248020 non-null  object
#  8   critical_flag          248020 non-null  object
#  9   record_date            248020 non-null  object
#  10  latitude               247745 non-null  object
#  11  longitude              247745 non-null  object
#  12  community_board        243757 non-null  object
#  13  council_district       243757 non-null  object
# ...

# %%
results_df.shape
# Out:
# (248020, 26)

# %%
#save to csv 
results_df.to_csv("restaurant_inspection.csv", index = False)

# %%
# Out:
# 248020

# %%
# Out:
#       camis                       dba       boro building  \
# 0  50115383              MAKE MY CAKE  Manhattan      409
# 1  50101317              THE FLO KISS  Manhattan     1802
# 2  50109634  QUICK EATS AT MASTERCARD  Manhattan      150
# 3  50124605                      None  Manhattan       37
# 4  50112662                      None  Manhattan      512
#
#                   street zipcode       phone          inspection_date  \
# 0       WEST  125 STREET   10027  9174405783  1900-01-01T00:00:00.000
# 1  65TH STREET TRANVERSE    None  6466453020  1900-01-01T00:00:00.000
# 2               5 AVENUE   10011  2152383000  1900-01-01T00:00:00.000
# 3      SAINT MARKS PLACE   10003  9174788158  1900-01-01T00:00:00.000
# 4               7 AVENUE   10018  9292676606  1900-01-01T00:00:00.000
#
#     critical_flag              record_date  ...         bbl   nta  \
# 0  Not Applicable  2022-08-27T06:00:16.000  ...  1019660066  MN09
# ...

# %%
df.shape
# Out:
# (248020, 26)
